# %% [markdown]
# **how does a vm work:** virtual computer bla bla passt schon
#
# **OS:** Debian, weil easier setup. *differences:* very minor. centos more stable, less updates, code is frozen. debian more flexible, more updates, can install new version, more up-to-date. centos benutzt net dpkg!! sondern RPM. more similarities than differences.
#
# **reason to use a vm**:
# - sandbox environment to test & try stuff
# - if you need a different operating system for *stuff*
# - or if you just want a different operating system to do shit in
# - or the same one, honestly, you can do whatever you want
# - dpkg < apt-get < apt < aptitude, aptitude has an interface
#
# **AppArmor**: security measure. administrator will allow or not allow processes / apps to do specific tasks. apparmor then either stops them or just complains, depending on the mode.
#
# ```sudo ufw status```
#
# ```sudo service ssh status```
#
# ```uname -a```
#
# ```getent group sudo```
#
# ```getent group user42```
#
# ```sudo adduser <username>```
#
# **passwd rules**: ```sudo nano /etc/login.defs```, ```sudo nano /etc/pam.d/common-password```
#
# ```sudo addgroup evaluating```
#
# ```sudo adduser <username> evaluating```
#
# ```getent group evaluating```
#
# **password policy**: <br>
# *advantages*: more secure. <br>
# *disadvantages*: annoying.
#
# ```sudo nano /etc/hostname```
#
# ```lsblk```
#
# **LVM**: *physical volume (PV)* is a physical thing, like a hard disk or an sd card, that gives actual, physical, space to a computer. you plug the PV on to a *volume group (VG)*. *logical volumes (LV)* are the partitions that are actually gonna be used. so, like virtual PVs. why do you do that? so you're not bound to the space on the physicl volumes, but can spread things wherever you want and don't need to worry about space. if you need more, just add another PV. the *LVM (Logical Volume Manager)* is the thing that makes it possible. it manages it.
#
# ```sudo adduser <username> sudo```
#
# ```ls /var/log/sudo```
#
# ```sudo ufw status```
#
# **ufw**: stands for uncomplicated firewall. interface for iptables, firewall for stuff like ssh.
#
# ```sudo ufw status```
#
# ```sudo ufw allow 8080```
#
# ```sudo ufw status```
#
# ```sudo ufw deny 8080```
#
# ```sudo ufw delete <number>```
#
# ```sudo service ssh status```
#
# **ssh**: secure shell. way to access remote servers/computers. works with encryption, so safe. very practical.
#
# ```sudo nano /etc/ssh/sshd_config```
#
# ```ssh -p 4242 <username>@10.12.250.192```
#
# ```sudo nano /home/shaas/monitoring.sh```
#
# **cron**: cron is a task manager that lets you execute tasks/commands at a certain time.
#
# ```sudo crontab -e```
#
# change this in the crontab file: <br>
# */1 * * * * bash /home/shaas/monitoring.sh <br>
# */1 * * * * sleep 30s && bash /home/shaas/monitoring.sh
#
# remove @reboot /path/to/monitoring.sh
#
# ```lsblk```
#
# ```sudo service lighttpd status```
#
# ```sudo service mariadb status```
#
# ```dpkg -l | grep php```

# %% [markdown]
# user42 group doesnt exist <br>
# last boot in monitoring script 2x? <br>

# %% [markdown]
# FdpFdp2021
